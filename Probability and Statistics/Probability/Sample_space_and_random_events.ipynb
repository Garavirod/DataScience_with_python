# %% [markdown]
# ### Events and random events
#
#
# __What's an event?__
#
#     Event which result is uncertain a priori.
#
# __Sample space :__
#
#     Set of all posibilities of an experiment.
#
# $$ \Omega =  \{1,2,3,4,....\} $$
#
# __Elemental event :__
#
#     Each element  from sample space.
#
# $$ \{1\} \{6\} \{4\} $$
#
# __compound event :__
#
#     Set of elemental events.
#
# * *Get an even number*$$ B = \{2,4,6\} $$
#
# * *Get an odd number*$$ C = \{1,3,5\} $$
#
# * *Get a number greater than 4*$$ D = \{5,6\} $$
#
#
# __Complementary event *X*:__
#
# It is composed of all the elementary events of $\Omgea$ that are not in *X*.

# %% [markdown]
# ### Sets operations

# %% [markdown]
# #### Union
#
# The union of two sets is a set containing all elements that are in A or in B (possibly both). For example, {1,2}∪{2,3}={1,2,3}. Thus, we can write x∈(A∪B) if and only if (x∈A) or (x∈B). Note that A∪B=B∪A.

# %% [markdown]
# #### Diference
#
# The difference (subtraction) is defined as follows. The set A−B consists of elements that are in A but not in B. For example if A={1,2,3} and B={3,5}, then A−B={1,2}. In Figure 1.8, A−B is shown by the shaded area using a Venn diagram. Note that:
#
# $$  A−B=A∩B^c $$

# %% [markdown]
# #### Intersection
#
# The intersection of two sets A and B, denoted by A∩B, consists of all elements that are both in A and B. For example:
#
# $$ \{1,2\}∩\{2,3\}=\{2\}$$

# %% [markdown]
# ### Venn Diagram
#
#
# A Venn diagram (also called primary diagram, set diagram or logic diagram) is a diagram that shows all possible logical relations between a finite collection of different sets. Each set is represented by a circle. The
#
# circle size represents the importance of the group. The groups are usually overlapping: the size of the overlap represents the intersection between both groups. It is unadvised to make Venn diagram with more than 3
#
# groups because it would become hard to read. In python, Venn diagram are realised using the venn2 and venn3 function of the matplotlib library according to the number of group you have. See here for module installation.

# %% [markdown]
# ### Operations sets using python

# %%
from matplotlib_venn import venn2, venn2_circles
import matplotlib.pyplot as plt

# %%
#Given the following sets    
A = {1,2,3}
B = {2, 3, 5}

plt.figure(figsize=(6, 8))

# %% [markdown]
# #### First way to call the 2 group Venn diagram:

# %%
venn2(subsets = (10, 5, 2), set_labels = ('Group A', 'Group B'))
plt.show()

# %% [markdown]
# #### Second way

# %%
venn2([A,B])
plt.show()

# %% [markdown]
# #### Third way

# %%
v = venn2(subsets=[A, B], set_labels=('A', 'B'))
v.get_label_by_id('10').set_text(A - B)
v.get_label_by_id('11').set_text(A.intersection(B))
v.get_label_by_id('01').set_text(B - A)
c = venn2_circles(subsets=[A, B], linestyle='dashed')
c[0].set_ls('solid')
plt.show()
